# %%
import csv
import datetime
import numpy as np
import math
import matplotlib.pyplot as plt
a=list()
b=list()
bb=list()
c=list()
with open('btc1st.csv', encoding='utf-8') as r_file:
    file_reader = csv.reader(r_file, delimiter = ",")
    count = 0
    for row in file_reader:
        if count != 0:
            x=float(row[2])
            a.append(x)
        count += 1
    print(len(a))
# Out:
# 1322

# %%
plt.plot(a)
plt.title('2012:11:28 - 2016:07:11')
plt.show()

# %%
o=0
u=0
for i in range(0,len(a)):
    if a[i]>o:
        o=a[i]
        u=i
print(u)
# Out:
# 366

# %%
with open('btc2nd.csv', encoding='utf-8') as r_file:
    file_reader = csv.reader(r_file, delimiter = ",")
    count = 0
    for row in file_reader:
        if count!=0 and count <=1322:
            x=float(row[2])
            b.append(x)
        if count!=0 and count<=329:
            x=float(row[2])
            bb.append(x)
        count += 1

print(len(b))
print(len(bb))
# Out:
# 1322
# 329

# %%
o=0
u=0
for i in range(0,len(b)):
    if b[i]>o:
        o=b[i]
        u=i
print(u)
# Out:
# 524

# %%
plt.plot(b)
plt.title('2016:07:11 - 2020:11:05')
plt.show()

# %%
plt.plot(bb)
plt.title('2016:07:11 + 329 дней')
plt.show()

# %%
with open('btc3rd.csv', encoding='utf-8') as r_file:
    file_reader = csv.reader(r_file, delimiter = ",")
    count = 0
    for row in file_reader:
        if count != 0:
            x=float(row[2])
            c.append(x)
        count += 1
    print(len(c))
# Out:
# 385

# %%
plt.plot(c)
plt.title('2020:11:05 - 2021:09:30')
plt.show()

# %%
def average(x):
    assert len(x) > 0
    return float(sum(x)) / len(x)

def pearson_def(x, y):
    assert len(x) == len(y)
    n = len(x)
    assert n > 0
    avg_x = average(x)
    avg_y = average(y)
    diffprod = 0
    xdiff2 = 0
    ydiff2 = 0
    for idx in range(n):
        xdiff = x[idx] - avg_x
        ydiff = y[idx] - avg_y
        diffprod += xdiff * ydiff
        xdiff2 += xdiff * xdiff
        ydiff2 += ydiff * ydiff

    return diffprod / math.sqrt(xdiff2 * ydiff2)
pearson_def(a, b)
# Out:
# 0.49213954439533764

# %%
pearson_def(bb, c)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8868/1947369266.py in <module>
# ----> 1 pearson_def(bb, c)
#
# ~\AppData\Local\Temp/ipykernel_8868/3036794444.py in pearson_def(x, y)
#       4
#       5 def pearson_def(x, y):
# ----> 6     assert len(x) == len(y)
#       7     n = len(x)
#       8     assert n > 0
#
# AssertionError:

# %%
pa =list()
for i in range(0,len(a)):
    q=a[i]/sum(a)
    pa.append(q)
Shannon2 = -np.sum(pa*np.log2(pa))
print(Shannon2)
# Out:
# 10.046863587538315

# %%
o=0
u=0
for i in range(0,len(c)):
    if c[i]>o:
        o=c[i]
        u=i
print(u)
# Out:
# 159
